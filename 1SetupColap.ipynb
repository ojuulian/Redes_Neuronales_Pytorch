# %% [markdown]
# ---
# ## Creando ruta de proyecto en drive
# ---
#
# Una forma de almacenar nuestra informacion y trabajar en drive de forma más eficiente es por medio de:

# %%
from google.colab import drive #importamos google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Al darse permisos, creamos nuestra ruta de la siguiente forma

# %%
# %cd "/content/drive/My Drive/Colab Notebooks/dl-pytorch"
# !ls
# Out:
# /content/drive/My Drive/Colab Notebooks/dl-pytorch
# 1SetupColap.ipynb	7_creando_red_neuronal_pytorch.ipynb  plot_helpers.py
# 2Tensores.ipynb		datasets			      __pycache__
# 6_capas_de_redes.ipynb	optimizers_viz.py		      utils.py

# %% [markdown]
# A continuación se procede a clonar el repositorio de github

# %%
#!git clone https://github.com/JuanPabloMF/dl-pytorch #clonamos un depoositorio de github

# %% [markdown]
# ---
# ## Cargando dataset.zip alojado en drive
# ---
#
# El data set es un conjunto de aproximadamente 1000 imágenes de manos que muestran dígitos (0,1,2,3,...etc)

# %%
# %cd "/content/drive/My Drive/Colab Notebooks/dl-pytorch/datasets"
# !ls
# Out:
# /content/drive/My Drive/Colab Notebooks/dl-pytorch/datasets
# 64x64_SIGNS  64x64_SIGNS.zip

# %%
# !unzip 64x64_SIGNS.zip #discomprimimos
# Out:
# Archive:  64x64_SIGNS.zip
#   inflating: 64x64_SIGNS/.DS_Store
# replace 64x64_SIGNS/train_signs/5_IMG_5556.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: 64x64_SIGNS/train_signs/5_IMG_5556.jpg
# replace 64x64_SIGNS/train_signs/3_IMG_6138.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: a
# error:  invalid response [a]
# replace 64x64_SIGNS/train_signs/3_IMG_6138.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: 64x64_SIGNS/train_signs/3_IMG_6138.jpg
#   inflating: 64x64_SIGNS/train_signs/3_IMG_6104.jpg
#   inflating: 64x64_SIGNS/train_signs/5_IMG_5595.jpg
#   inflating: 64x64_SIGNS/train_signs/5_IMG_5581.jpg
#   inflating: 64x64_SIGNS/train_signs/1_IMG_4495.jpg
#   inflating: 64x64_SIGNS/train_signs/4_IMG_5357.jpg
#   inflating: 64x64_SIGNS/train_signs/2_IMG_4648.jpg
#   inflating: 64x64_SIGNS/train_signs/4_IMG_5343.jpg
#   inflating: 64x64_SIGNS/train_signs/2_IMG_4660.jpg
#   inflating: 64x64_SIGNS/train_signs/4_IMG_5419.jpg
# ...

# %% [markdown]
# ---
# # Importando librerias creadas en extensión .py
# ---
#
# Para importar una libreria creada anteriormente con extension .py se procede a:
#
# * Usar un módulo en python llamado **sys** en donde se puede colocar las rutas donde buscará python las librerias modificando la ruta en el repositorio a uno de googleDrive, todo lo anterior para que cuando se realice un import se llame las librerias alojadas en la ruta específica.

# %%
import sys   #importamos el modelos 
course_path = '/content/drive/My Drive/Colab Notebooks/dl-pytorch' #le damos una ruta (path de la carpeta pythorch actual)

sys.path.append(course_path) #que la recuerde siempre

# %%
import plot_helpers #vemos que podemos importat las librerias para las imágenes

# %%
dir(plot_helpers) #vemos las cosas que tienen adentro la libreria
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'french',
#  'imshow',
#  'io',
#  'np',
#  'plot_cube',
#  'plot_rgb_image',
#  'plt',
#  'torch',
#  'visualize_model']

# %% [markdown]
# Al llamar **imshow** se ordenan las imágenes en un grid para poder usarlas
