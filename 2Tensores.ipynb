# %%
from google.colab import drive #importamos google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/My Drive/Colab Notebooks/dl-pytorch/datasets"
# !ls
# Out:
# /content/drive/My Drive/Colab Notebooks/dl-pytorch/datasets
# 64x64_SIGNS  64x64_SIGNS.zip

# %%
# !unzip 64x64_SIGNS.zip #discomprimimos
# Out:
# Archive:  64x64_SIGNS.zip
# replace 64x64_SIGNS/.DS_Store? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: 64x64_SIGNS/.DS_Store
#   inflating: 64x64_SIGNS/train_signs/5_IMG_5556.jpg
#   inflating: 64x64_SIGNS/train_signs/3_IMG_6138.jpg
#   inflating: 64x64_SIGNS/train_signs/3_IMG_6104.jpg
#   inflating: 64x64_SIGNS/train_signs/5_IMG_5595.jpg
#   inflating: 64x64_SIGNS/train_signs/5_IMG_5581.jpg
#   inflating: 64x64_SIGNS/train_signs/1_IMG_4495.jpg
#   inflating: 64x64_SIGNS/train_signs/4_IMG_5357.jpg
#   inflating: 64x64_SIGNS/train_signs/2_IMG_4648.jpg
#   inflating: 64x64_SIGNS/train_signs/4_IMG_5343.jpg
#   inflating: 64x64_SIGNS/train_signs/2_IMG_4660.jpg
#   inflating: 64x64_SIGNS/train_signs/4_IMG_5419.jpg
#   inflating: 64x64_SIGNS/train_signs/1_IMG_4456.jpg
#   inflating: 64x64_SIGNS/train_signs/4_IMG_5394.jpg
#   inflating: 64x64_SIGNS/train_signs/1_IMG_4442.jpg
#   inflating: 64x64_SIGNS/train_signs/5_IMG_5620.jpg
# ...

# %%
import sys   #importamos el modelos 
course_path = '/content/drive/My Drive/Colab Notebooks/dl-pytorch' #le damos una ruta (path de la carpeta pythorch actual)

sys.path.append(course_path) #que la recuerde siempre

# %%
import plot_helpers #vemos que podemos importat las librerias para las imágenes
dir(plot_helpers) #vemos las cosas que tienen adentro la libreria
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'french',
#  'imshow',
#  'io',
#  'np',
#  'plot_cube',
#  'plot_rgb_image',
#  'plt',
#  'torch',
#  'visualize_model']

# %% [markdown]
# ---
# # TENSORES
# ---

# %% [markdown]
# ![texto alternativo](https://i.imgur.com/21Ln3BP.png)

# %%
import torch
torch.__version__
# Out:
# '1.7.0+cu101'

# %%
A = torch.randn((8,3,5))
A.size()
# Out:
# torch.Size([8, 3, 5])

# %%
A.size() == (8,3,5)
# Out:
# True

# %% [markdown]
# Accediendo a valores del tensor

# %%
A[0][0][0]
# Out:
# tensor(-1.0658)

# %%
A[0,:,0]   #una columna con slice
A[0,0,:]
# Out:
# tensor([-1.0658, -2.1005, -1.3542, -0.2442,  0.5386])

# %%
A[0,0,:]   #una columna con slice igual que las listas
# Out:
# tensor([-1.0658, -2.1005, -1.3542, -0.2442,  0.5386])

# %%
C = torch.zeros((5,5))
C.dtype
# Out:
# torch.float32

# %%
D = torch.randint(2,(5,5))   #El 2 me indica que solo serán 0 o 1, (5,5) es el tamaño
D
# Out:
# tensor([[1, 1, 1, 1, 1],
#         [0, 0, 0, 1, 0],
#         [1, 0, 1, 1, 1],
#         [1, 1, 0, 0, 1],
#         [1, 0, 1, 0, 0]])

# %%
D.dtype # Observese que es tensor con valores enteros, diferente a C que es flotante
# Out:
# torch.int64

# %% [markdown]
# Observemos a la hora de sumar tensores

# %%
C+D
# Out:
# tensor([[1., 1., 1., 1., 1.],
#         [0., 0., 0., 1., 0.],
#         [1., 0., 1., 1., 1.],
#         [1., 1., 0., 0., 1.],
#         [1., 0., 1., 0., 0.]])

# %%
print(C + D.int())
print((C + D.int()).dtype)
# Out:
# tensor([[1., 1., 1., 1., 1.],
#         [0., 0., 0., 1., 0.],
#         [1., 0., 1., 1., 1.],
#         [1., 1., 0., 0., 1.],
#         [1., 0., 1., 0., 0.]])
# torch.float32

# %%
torch.set_default_tensor_type('torch.FloatTensor')   #Para que por defecto al hacer operaciones los tensores den flotantes

# %% [markdown]
# ---
# # Tensores de CPU a TPU
# ---

# %%
C.device
# Out:
# device(type='cpu')

# %% [markdown]
# Anteriormente se obsdervó que está coriendo en CPU, ahora identifiquemos si está habilitada la TPU

# %%
torch.cuda.is_available()
# Out:
# False

# %% [markdown]
# Por el momento la TPU no está disponible, luego hay que configurar el notebook **(entorno de ejecucion)>>(TPU)**

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
x = torch.randn(3,5) #cpu
y = torch.ones_like(x, device=device) #gpu

# %%
x = x.to(device) #gpu

# %%
z = x + y

# %%
print(z)
print(z.cpu())
# Out:
# tensor([[ 1.7046,  2.9763,  2.4388,  2.0839, -0.4496],
#         [-0.1800,  0.0769, -0.3804,  2.5077,  0.7124],
#         [ 1.6097,  2.3661,  0.4185,  2.1999, -0.2286]], device='cuda:0')
# tensor([[ 1.7046,  2.9763,  2.4388,  2.0839, -0.4496],
#         [-0.1800,  0.0769, -0.3804,  2.5077,  0.7124],
#         [ 1.6097,  2.3661,  0.4185,  2.1999, -0.2286]])

# %% [markdown]
# ## Importando dataSet de Pytorch

# %%
from torchvision import datasets   #torchvision trae muchos datasets para usar

# %%
dir(datasets)
# Out:
# ['CIFAR10',
#  'CIFAR100',
#  'Caltech101',
#  'Caltech256',
#  'CelebA',
#  'Cityscapes',
#  'CocoCaptions',
#  'CocoDetection',
#  'DatasetFolder',
#  'EMNIST',
#  'FakeData',
#  'FashionMNIST',
#  'Flickr30k',
#  'Flickr8k',
#  'HMDB51',
#  'ImageFolder',
#  'ImageNet',
#  'KMNIST',
#  'Kinetics400',
#  'LSUN',
#  'LSUNClass',
#  'MNIST',
#  'Omniglot',
#  'PhotoTour',
#  'Places365',
#  'QMNIST',
#  'SBDataset',
#  'SBU',
#  'SEMEION',
#  'STL10',
#  'SVHN',
#  'UCF101',
#  'USPS',
#  'VOCDetection',
#  'VOCSegmentation',
#  'VisionDataset',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'caltech',
#  'celeba',
#  'cifar',
#  'cityscapes',
#  'coco',
#  'fakedata',
#  'flickr',
#  'folder',
#  'hmdb51',
#  'imagenet',
#  'kinetics',
#  'lsun',
#  'mnist',
#  'omniglot',
#  'phototour',
#  'places365',
#  'sbd',
#  'sbu',
#  'semeion',
#  'stl10',
#  'svhn',
# ...

# %%
cifar = datasets.CIFAR10('/content/drive/My Drive/Colab Notebooks/dl-pytorch/datasets', download=True)
# Out:
# ...
# Extracting /content/drive/My Drive/Colab Notebooks/dl-pytorch/datasets/cifar-10-python.tar.gz to /content/drive/My Drive/Colab Notebooks/dl-pytorch/datasets

# %%
len(cifar)
# Out:
# 50000

# %%
cifar.data
# Out:
# array([[[[ 59,  62,  63],
#          [ 43,  46,  45],
#          [ 50,  48,  43],
#          ...,
#          [158, 132, 108],
#          [152, 125, 102],
#          [148, 124, 103]],
#
#         [[ 16,  20,  20],
#          [  0,   0,   0],
#          [ 18,   8,   0],
#          ...,
#          [123,  88,  55],
#          [119,  83,  50],
#          [122,  87,  57]],
#
#         [[ 25,  24,  21],
#          [ 16,   7,   0],
#          [ 49,  27,   8],
#          ...,
#          [118,  84,  50],
#          [120,  84,  50],
#          [109,  73,  42]],
#
#         ...,
#
#         [[208, 170,  96],
#          [201, 153,  34],
#          [198, 161,  26],
#          ...,
#          [160, 133,  70],
#          [ 56,  31,   7],
#          [ 53,  34,  20]],
#
#         [[180, 139,  96],
#          [173, 123,  42],
#          [186, 144,  30],
#          ...,
#          [184, 148,  94],
#          [ 97,  62,  34],
#          [ 83,  53,  34]],
#
#         [[177, 144, 116],
# ...

# %%
data = torch.Tensor(cifar.data)

# %%
data
# Out:
# tensor([[[[ 59.,  62.,  63.],
#           [ 43.,  46.,  45.],
#           [ 50.,  48.,  43.],
#           ...,
#           [158., 132., 108.],
#           [152., 125., 102.],
#           [148., 124., 103.]],
#
#          [[ 16.,  20.,  20.],
#           [  0.,   0.,   0.],
#           [ 18.,   8.,   0.],
#           ...,
#           [123.,  88.,  55.],
#           [119.,  83.,  50.],
#           [122.,  87.,  57.]],
#
#          [[ 25.,  24.,  21.],
#           [ 16.,   7.,   0.],
#           [ 49.,  27.,   8.],
#           ...,
#           [118.,  84.,  50.],
#           [120.,  84.,  50.],
#           [109.,  73.,  42.]],
#
#          ...,
#
#          [[208., 170.,  96.],
#           [201., 153.,  34.],
#           [198., 161.,  26.],
#           ...,
#           [160., 133.,  70.],
#           [ 56.,  31.,   7.],
#           [ 53.,  34.,  20.]],
#
#          [[180., 139.,  96.],
#           [173., 123.,  42.],
#           [186., 144.,  30.],
#           ...,
# ...

# %%
data.size()
# Out:
# torch.Size([50000, 32, 32, 3])
